# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import random
from sklearn import preprocessing, metrics
from joblib import load, dump
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import RepeatedKFold
import seaborn as sns

# %%
sea_cv = load('/gws/nopw/j04/aopp/jowanf/pickled/sea_area_cv')
land_cv = load('/gws/nopw/j04/aopp/jowanf/pickled/land_area_cv')

# %%
ax = sns.stripplot(data=np.transpose(sea_cv), color="k", alpha=0.5)
sns.boxplot(data=np.transpose(sea_cv), color="cyan", saturation=0.5, whis=10)
ax.set(xlabel='Area rings removed', ylabel='Model accuracy',title='Sea model accuracy with domain size')
# Out:
# /home/users/jowanf/miniconda3/envs/jasenv/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Area rings removed'),
#  Text(0, 0.5, 'Model accuracy'),
#  Text(0.5, 1.0, 'Sea model accuracy with domain size')]

# %%
ax = sns.stripplot(data=np.transpose(land_cv), color="k", alpha=0.5)
sns.boxplot(data=np.transpose(land_cv), color="cyan", saturation=0.5, whis=10)
ax.set(xlabel='Area rings removed', ylabel='Model accuracy',title='Land model accuracy with domain size')
# Out:
# /home/users/jowanf/miniconda3/envs/jasenv/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:k'` for same effect.
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Area rings removed'),
#  Text(0, 0.5, 'Model accuracy'),
#  Text(0.5, 1.0, 'Land model accuracy with domain size')]
